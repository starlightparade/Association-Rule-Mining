# %%
import sys
import os
import itertools
import math
from collections import Counter


def read_csv(filepath):
    '''Read transactions from csv_file specified by filepath
    Args:
        filepath (str): the path to the file to be read

    Returns:
        list: a list of lists, where each component list is a list of string representing a transaction

    '''

    transactions = []
    with open(filepath, 'r') as f:
        lines = f.readlines()
        for line in lines:
            transactions.append(line.strip().split(',')[:-1])
    return transactions

# %%
class Hash_Node:
    """
    Class which represents node in a hash tree.
    """

    def __init__(self):
        self.children = {}
        self.isLeaf = True
        self.bucket = {}


class Hash_Tree:
    """
    Wrapper class for HTree instance
    """

    def __init__(self, max_leaf_cnt, max_child_cnt):
        self.root = Hash_Node()
        self.max_leaf_cnt = max_leaf_cnt
        self.max_child_cnt = max_child_cnt
        self.frequent_itemsets = []

    def recur_insert(self, node, itemset, index, cnt):
        """
        Recursively adds nodes inside the tree and if required splits leaf node and
        redistributes itemsets among child converting itself into intermediate node.
        :param node:
        :param itemset:
        :param index:
        :return:
        """
        if index == len(itemset):
            # last bucket so just insert
            if itemset in node.bucket:
                node.bucket[itemset] += cnt
            else:
                node.bucket[itemset] = cnt
            return

        if node.isLeaf:

            if itemset in node.bucket:
                node.bucket[itemset] += cnt
            else:
                node.bucket[itemset] = cnt
            if len(node.bucket) == self.max_leaf_cnt:
                # bucket has reached its maximum capacity and its intermediate node so
                # split and redistribute entries.
                for old_itemset, old_cnt in node.bucket.items():

#                     hash_key = self.hash(old_itemset[index])
                    hash_key = self.hash(old_itemset[index])
                    if hash_key not in node.children:
                        node.children[hash_key] = Hash_Node()
                    self.recur_insert(node.children[hash_key], old_itemset, index + 1, old_cnt)
                # there is no point in having this node's bucket
                # so just delete it
                del node.bucket
                node.isLeaf = False
        else:
            hash_key = self.hash(itemset[index])
            if hash_key not in node.children:
                node.children[hash_key] = Hash_Node()
            self.recur_insert(node.children[hash_key], itemset, index + 1, cnt)

    def insert(self, itemset):
        # as list can't be hashed we need to convert this into tuple
        # which can be easily hashed in leaf node buckets
#         print("itemset:",itemset)
        itemset = tuple(itemset)
#         print("tuple itemset:",itemset)
        self.recur_insert(self.root, itemset, 0, 0)

    def add_support(self, itemset):
#         print("add support for ",itemset)
        runner = self.root
        itemset = tuple(itemset)
        index = 0
        while True:
            if runner.isLeaf:
                if itemset in runner.bucket:
                    runner.bucket[itemset] += 1
                break
            hash_key = self.hash(itemset[index])
            if hash_key in runner.children:
                runner = runner.children[hash_key]
            else:
                break
            index += 1

    def dfs(self, node, support_cnt):
        if node.isLeaf:
            for key, value in node.bucket.items():
                if value >= support_cnt:
#                     self.frequent_itemsets.append(list(key))
                    self.frequent_itemsets.append((list(key),value))
                    # print key, value, support_cnt
            return

        for child in node.children.values():
            self.dfs(child, support_cnt)

    def get_frequent_itemsets(self, support_cnt):
        """
        Returns all frequent itemsets which can be considered for next level
        :param support_cnt: Minimum cnt required for itemset to be considered as frequent
        :return:
        """
        self.frequent_itemsets = []
        self.dfs(self.root, support_cnt)
        return self.frequent_itemsets

    def hash(self, val):
#         print("value:",val)
        return val % self.max_child_cnt

# %%
# To be implemented
def generate_frequent_itemset(transactions, minsup):
    '''Generate the frequent itemsets from transactions
    Args:
        transactions (list): a list of lists, where each component list is a list of string representing a transaction
        minsup (float): specifies the minsup for mining

    Returns:
        list: a list of frequent itemsets and each itemset is represented as a list string

    Example:
        Output: [['margarine'], ['ready soups'], ['citrus fruit','semi-finished bread'], ['tropical fruit','yogurt','coffee'], ['whole milk']]
        The meaning of the output is as follows: itemset {margarine}, {ready soups}, {citrus fruit, semi-finished bread}, {tropical fruit, yogurt, coffee}, {whole milk} are all frequent itemset

    '''
    # generate frequent itemset of single items
    
    print("transaction:",len(transactions))
    items = []
    support_count = []
    unique_items = []
    frequent_k = []
    transactions_index = []
    frequent_itemsets = [[]]
    
    for transaction in transactions:
        for item in transaction:
            items.append(item)
    
    num_transactions = len(transactions)
    
    
    for item in items:
        if not (item in unique_items):
            unique_items.append(item)
            
    unique_items = sorted(unique_items)
    unique_items_index = list(range(1,len(unique_items)+1))
    
#     print("unique_items_index:",unique_items_index)
    unique_items_map = {} #item, number

    #get frequent items of k=1
    
    i = 1
    
    for item in unique_items:
        unique_items_map[item] = i
        i += 1    
    
    frequent_items = Counter(x for sublist in transactions for x in sublist)
    for name, freq in frequent_items.items():
        if freq/num_transactions >= minsup:
            templist = []
            templist.append(unique_items_map.get(name))
            if not len(templist) == 0:
                frequent_k.append(templist)
                support_count.append((templist, freq))

    #frequent_k = sorted(frequent_k)
    
    print("frequent_k:",frequent_k)
    
    unique_items_map_inversed = dict((v,k) for k, v in unique_items_map.items())   #number, item
#     print("unique_items_map_inversed:", unique_items_map_inversed)
    
    for transaction in transactions:
        templist = []
        for item in transaction:  
            templist.append(unique_items_map.get(item))
        transactions_index.append(templist)
        
#     print("transactions_index:",transactions_index)

    frequent_itemsets = frequent_k
#     print("frequent_itemsets:",frequent_itemsets)


    k = 2
    while len(frequent_k) > 0:
        print("")
        print("loop ",k," start")
        # 1 - candidate generation
        candidates = []
        
        for i in range (0,len(frequent_k)):
            item_to_merge_1 = frequent_k[i]
#             print("i: ",i)
            for j in range (i+1,len(frequent_k)):
#                 print("j: ",j)
                item_to_merge_2 = frequent_k[j]
                new_itemset = []
                
                if(k <= 2):
                    new_itemset.extend(item_to_merge_1)
                    new_itemset.extend(item_to_merge_2)
                else:
#                     print("compare 1:",item_to_merge_1)
#                     print("compare 2:",item_to_merge_2)
                    if check_same_array(item_to_merge_1[0:k-2],item_to_merge_2[0:k-2]):
#                         print("1: ",item_to_merge_1)
#                         print("2: ",item_to_merge_2[k-2:k-1])
                        new_itemset = [x for x in item_to_merge_1]
                        new_itemset.extend(item_to_merge_2[k-2:k-1]) #Combine (k-1)-Itemset to k-Itemset 

                if new_itemset:
#                     print("new_itemset:",new_itemset)
#                     print(" " )
                    new_itemset = sorted(new_itemset) 
                    out_list = []
                    candidate_not_prune = True
                    # 2 - candidate_pruning

                    out_list_temp = sum([list(itertools.combinations(new_itemset, i)) for i in range(len(new_itemset))],[])
                    out_list = [list(p) for p in out_list_temp if list(p) != []]
                                                    
                    for element in out_list:
#                         print("Check element:",element," - ",element in frequent_itemsets)
                        if not (element in frequent_itemsets):
#                             print("prune result: False")
                            candidate_not_prune = False
                            break
                    
                    if candidate_not_prune:
#                         print("prune result: True")
                        candidates.append(new_itemset)                   
            
        #3 support counting and candidate elimination
        
#         print("candidates:",candidates)
        k_subsets = []
        for itemset in transactions_index:
            k_subsets.extend(map(list, itertools.combinations(itemset, k)))
            
#         k_subsets = [list(x) for x in list(itertools.combinations(unique_items_index, k))]
              
        hash_tree = Hash_Tree(max_child_cnt=4, max_leaf_cnt=5)
        
        for itemset in candidates:
        # add this itemset to hashtree
            hash_tree.insert(itemset)
        
#         print("k-subsets for k =",k,":",k_subsets)
        
        for subset in k_subsets:
            subset = sorted(subset)
            hash_tree.add_support(subset)
            
#         print("support:",math.ceil(minsup*num_transactions))
        new_frequent = hash_tree.get_frequent_itemsets(math.ceil(minsup*num_transactions))
        
#         print ("new_frequent:",new_frequent)
        
        frequent_k = [list(x[0]) for x in new_frequent]
        frequent_k.sort()
        frequent_itemsets.extend(frequent_k)
#         print("frequent itemsets:",frequent_itemsets)
        
        k += 1
        
#         for new_freq in new_frequent:
#             print("new_freq:",new_freq)
#             support_count[list(new_freq[0])] = int(new_freq[1])
#         support_count = dict((x, y) for x, y in new_frequent)  
        support_count.extend(new_frequent)
    
#         print("support_count:",support_count)
    frequent_itemset_string = []
    for itemset in frequent_itemsets:
        item_string = []
        for item in itemset:
            item_string.append(unique_items_map_inversed.get(item))
        frequent_itemset_string.append(item_string)
        
    support_count_string = []
    for support in support_count:
        support_string = []
        for x in support[0]:
            support_string.append(unique_items_map_inversed.get(x))
        support_count_string.append((support_string, support[1]))
        
    print("final frequent itemsets:",frequent_itemset_string)
#     print("final support_count:", support_count_string)
    return frequent_itemset_string, support_count_string

def check_same_array(list_1, list_2):
    for i in range(0,len(list_1)):
        if list_1[i] != list_2[i]:
            return False
    return True

# %%
transactions = read_csv("Data/Groceries.csv")
generate_frequent_itemset(transactions, 0.01)
# Out:
# transaction: 9835
# frequent_k: [[32], [134], [90], [159], [168], [36], [167], [111], [41], [104], [37], [87], [17], [124], [2], [13], [114], [165], [14], [30], [42], [55], [49], [10], [58], [140], [29], [153], [66], [97], [105], [146], [18], [107], [117], [47], [125], [60], [130], [162], [21], [22], [132], [16], [135], [12], [70], [75], [96], [113], [11], [163], [67], [46], [51], [152], [94], [71], [26], [69], [8], [110], [100], [28], [76], [65], [23], [133], [121], [148], [56], [129], [63], [25], [101], [72], [166], [137], [106], [34], [141], [19], [61], [48], [92], [95], [84], [123]]
#
# loop  2  start
#
# loop  3  start
#
# loop  4  start
# final frequent itemsets: [['citrus fruit'], ['semi-finished bread'], ['margarine'], ['tropical fruit'], ['yogurt'], ['coffee'], ['whole milk'], ['pip fruit'], ['cream cheese'], ['other vegetables'], ['condensed milk'], ['long life bakery product'], ['butter'], ['rolls/buns'], ['UHT-milk'], ['bottled beer'], ['pot plants'], ['white bread'], ['bottled water'], ['chocolate'], ['curd'], ['flour'], ['dishes'], ['beef'], ['frankfurter'], ['soda'], ['chicken'], ['sugar'], ['fruit/vegetable juice'], ['newspapers'], ['packaged fruit/vegetables'], ['specialty bar'], ['butter milk'], ['pastry'], ['processed cheese'], ['detergent'], ['root vegetables'], ['frozen dessert'], ['salty snack'], ['waffles'], ['candy'], ['canned beer'], ['sausage'], ['brown bread'], ['shopping bags'], ['beverages'], ['hamburger meat'], ['hygiene articles'], ['napkins'], ['pork'], ['berries'], ['whipped/sour cream'], ['grapes'], ['dessert'], ['domestic eggs'], ['spread cheese'], ['misc. beverages'], ['hard cheese'], ['cat food'], ['ham'], ['baking powder'], ['pickled vegetables'], ['oil'], ['chewing gum'], ['ice cream'], ['frozen vegetables'], ['canned fish'], ['seasonal products'], ['red/blush wine'], ['specialty chocolate'], ['flower (seeds)'], ['salt'], ['frozen meals'], ['canned vegetables'], ['onions'], ['herbs'], ['white wine'], ['sliced cheese'], ['pasta'], ['cling film/bags'], ['soft cheese'], ['cake bar'], ['frozen fish'], ['dish cleaner'], ['meat'], ['mustard'], ['liquor'], ['roll products'], ['beef', 'other vegetables'], ['beef', 'rolls/buns'], ['beef', 'root vegetables'], ['beef', 'whole milk'], ['beef', 'yogurt'], ['berries', 'other vegetables'], ['berries', 'whole milk'], ['berries', 'yogurt'], ['bottled beer', 'bottled water'], ['bottled beer', 'other vegetables'], ['bottled beer', 'rolls/buns'], ['bottled beer', 'soda'], ['bottled beer', 'whole milk'], ['bottled water', 'citrus fruit'], ['bottled water', 'fruit/vegetable juice'], ['bottled water', 'margarine'], ['bottled water', 'newspapers'], ['bottled water', 'other vegetables'], ['bottled water', 'pip fruit'], ['bottled water', 'rolls/buns'], ['bottled water', 'root vegetables'], ['bottled water', 'sausage'], ['bottled water', 'shopping bags'], ['bottled water', 'soda'], ['bottled water', 'tropical fruit'], ['bottled water', 'whole milk'], ['bottled water', 'yogurt'], ['brown bread', 'other vegetables'], ['brown bread', 'rolls/buns'], ['brown bread', 'root vegetables'], ['brown bread', 'sausage'], ['brown bread', 'soda'], ['brown bread', 'tropical fruit'], ['brown bread', 'whole milk'], ['brown bread', 'yogurt'], ['butter', 'other vegetables'], ['butter', 'rolls/buns'], ['butter', 'root vegetables'], ['butter', 'whipped/sour cream'], ['butter', 'whole milk'], ['butter', 'yogurt'], ['butter milk', 'other vegetables'], ['butter milk', 'whole milk'], ['canned beer', 'rolls/buns'], ['canned beer', 'shopping bags'], ['canned beer', 'soda'], ['chicken', 'other vegetables'], ['chicken', 'root vegetables'], ['chicken', 'whole milk'], ['chocolate', 'other vegetables'], ['chocolate', 'rolls/buns'], ['chocolate', 'soda'], ['chocolate', 'whole milk'], ['citrus fruit', 'domestic eggs'], ['citrus fruit', 'fruit/vegetable juice'], ['citrus fruit', 'other vegetables'], ['citrus fruit', 'pip fruit'], ['citrus fruit', 'rolls/buns'], ['citrus fruit', 'root vegetables'], ['citrus fruit', 'sausage'], ['citrus fruit', 'soda'], ['citrus fruit', 'tropical fruit'], ['citrus fruit', 'whipped/sour cream'], ['citrus fruit', 'whole milk'], ['citrus fruit', 'yogurt'], ['coffee', 'other vegetables'], ['coffee', 'rolls/buns'], ['coffee', 'whole milk'], ['cream cheese', 'other vegetables'], ['cream cheese', 'whole milk'], ['cream cheese', 'yogurt'], ['curd', 'other vegetables'], ['curd', 'rolls/buns'], ['curd', 'root vegetables'], ['curd', 'tropical fruit'], ['curd', 'whipped/sour cream'], ['curd', 'whole milk'], ['curd', 'yogurt'], ['dessert', 'other vegetables'], ['dessert', 'whole milk'], ['domestic eggs', 'other vegetables ...
# final support_count: [(['citrus fruit'], 814), (['semi-finished bread'], 174), (['margarine'], 576), (['tropical fruit'], 1032), (['yogurt'], 1372), (['coffee'], 571), (['whole milk'], 2513), (['pip fruit'], 744), (['cream cheese'], 390), (['other vegetables'], 1903), (['condensed milk'], 101), (['long life bakery product'], 368), (['butter'], 545), (['rolls/buns'], 1809), (['UHT-milk'], 329), (['bottled beer'], 792), (['pot plants'], 170), (['white bread'], 414), (['bottled water'], 1087), (['chocolate'], 488), (['curd'], 524), (['flour'], 171), (['dishes'], 173), (['beef'], 516), (['frankfurter'], 580), (['soda'], 1715), (['chicken'], 422), (['sugar'], 333), (['fruit/vegetable juice'], 711), (['newspapers'], 785), (['packaged fruit/vegetables'], 128), (['specialty bar'], 269), (['butter milk'], 275), (['pastry'], 875), (['processed cheese'], 163), (['detergent'], 189), (['root vegetables'], 1072), (['frozen dessert'], 106), (['salty snack'], 372), (['waffles'], 378), (['candy'], 294), (['canned beer'], 764), (['sausage'], 924), (['brown bread'], 638), (['shopping bags'], 969), (['beverages'], 256), (['hamburger meat'], 327), (['hygiene articles'], 324), (['napkins'], 515), (['pork'], 567), (['berries'], 327), (['whipped/sour cream'], 705), (['grapes'], 220), (['dessert'], 365), (['domestic eggs'], 624), (['spread cheese'], 110), (['misc. beverages'], 279), (['hard cheese'], 241), (['cat food'], 229), (['ham'], 256), (['baking powder'], 174), (['pickled vegetables'], 176), (['oil'], 276), (['chewing gum'], 207), (['ice cream'], 246), (['frozen vegetables'], 473), (['canned fish'], 148), (['seasonal products'], 140), (['red/blush wine'], 189), (['specialty chocolate'], 299), (['flower (seeds)'], 102), (['salt'], 106), (['frozen meals'], 279), (['canned vegetables'], 106), (['onions'], 305), (['herbs'], 160), (['white wine'], 187), (['sliced cheese'], 241), (['pasta'], 148), (['cling film/bags'], 112), (['soft cheese'], 168), (['cake bar'], 130), (['frozen fish'], 115), (['dish cleaner'], 103), (['meat'], 254), (['mustard'], 118), (['liquor'], 109), (['roll products'], 101), (['citrus fruit', 'fruit/vegetable juice'], 102), (['other vegetables', 'salty snack'], 106), (['other vegetables', 'waffles'], 99), (['citrus fruit', 'tropical fruit'], 196), (['citrus fruit', 'whole milk'], 300), (['citrus fruit', 'pip fruit'], 136), (['citrus fruit', 'whipped/sour cream'], 107), (['citrus fruit', 'domestic eggs'], 102), (['other vegetables', 'tropical fruit'], 353), (['rolls/buns', 'tropical fruit'], 242), (['soda', 'tropical fruit'], 205), (['sausage', 'tropical fruit'], 137), (['brown bread', 'tropical fruit'], 105), (['napkins', 'tropical fruit'], 99), (['coffee', 'whole milk'], 184), (['other vegetables', 'whole milk'], 736), (['rolls/buns', 'whole milk'], 557), (['soda', 'whole milk'], 394), (['sausage', 'whole milk'], 294), (['brown bread', 'whole milk'], 248), (['napkins', 'whole milk'], 194), (['oil', 'whole milk'], 111), (['other vegetables', 'pip fruit'], 257), (['other vegetables', 'pastry'], 222), (['other vegetables', 'shopping bags'], 228), (['other vegetables', 'whipped/sour cream'], 284), (['rolls/buns', 'shopping bags'], 192), (['rolls/buns', 'whipped/sour cream'], 144), (['soda', 'whipped/sour cream'], 114), (['sausage', 'shopping bags'], 154), (['citrus fruit', 'yogurt'], 213), (['citrus fruit', 'other vegetables'], 284), (['citrus fruit', 'rolls/buns'], 165), (['citrus fruit', 'soda'], 126), (['citrus fruit', 'sausage'], 111), (['other vegetables', 'yogurt'], 427), (['rolls/buns', 'yogurt'], 338), (['soda', 'yogurt'], 269), (['sausage', 'yogurt'], 193), (['brown bread', 'yogurt'], 143), (['napkins', 'yogurt'], 121), (['coffee', 'other vegetables'], 132), (['coffee', 'rolls/buns'], 108), (['other vegetables', 'rolls/buns'], 419), (['other vegetables', 'soda'], 322), (['other vegetables', 'sausage'], 265), (['brown bread', 'other vegetables'], 184), (['napkins', 'other vegetables'], 142), (['rolls/buns', 'soda'], 377),  ...
# ([['citrus fruit'],
#   ['semi-finished bread'],
#   ['margarine'],
#   ['tropical fruit'],
#   ['yogurt'],
#   ['coffee'],
#   ['whole milk'],
#   ['pip fruit'],
#   ['cream cheese'],
#   ['other vegetables'],
#   ['condensed milk'],
#   ['long life bakery product'],
#   ['butter'],
#   ['rolls/buns'],
#   ['UHT-milk'],
#   ['bottled beer'],
#   ['pot plants'],
#   ['white bread'],
#   ['bottled water'],
#   ['chocolate'],
#   ['curd'],
#   ['flour'],
#   ['dishes'],
#   ['beef'],
#   ['frankfurter'],
#   ['soda'],
#   ['chicken'],
#   ['sugar'],
#   ['fruit/vegetable juice'],
#   ['newspapers'],
#   ['packaged fruit/vegetables'],
#   ['specialty bar'],
#   ['butter milk'],
#   ['pastry'],
#   ['processed cheese'],
#   ['detergent'],
#   ['root vegetables'],
#   ['frozen dessert'],
#   ['salty snack'],
#   ['waffles'],
#   ['candy'],
#   ['canned beer'],
#   ['sausage'],
#   ['brown bread'],
#   ['shopping bags'],
#   ['beverages'],
#   ['hamburger meat'],
#   ['hygiene articles'],
#   ['napkins'],
#   ['pork'],
#   ['berries'],
#   ['whipped/sour cream'],
#   ['grapes'],
#   ['dessert'],
#   ['domestic eggs'],
#   ['spread cheese'],
#   ['misc. beverages'],
#   ['hard cheese'],
#   ['cat food'],
#   ['ham'],
#   ['baking powder'],
#   ['pickled vegetables'],
#   ['oil'],
#   ['chewing gum'],
#   ['ice cream'],
#   ['frozen vegetables'],
#   ['canned fish'],
#   ['seasonal products'],
#   ['red/blush wine'],
#   ['specialty chocolate'],
#   ['flower (seeds)'],
#   ['salt'],
#   ['frozen meals'],
#   ['canned vegetables'],
#   ['onions'],
#   ['herbs'],
#   ['white wine'],
#   ['sliced cheese'],
#   ['pasta'],
#   ['cling film/bags'],
#   ['soft cheese'],
#   ['cake bar'],
#   ['frozen fish'],
#   ['dish cleaner'],
#   ['meat'],
#   ['mustard'],
#   ['liquor'],
#   ['roll products'],
#   ['beef', 'other vegetables'],
#   ['beef', 'rolls/buns'],
#   ['beef', 'root vegetables'],
#   ['beef', 'whole milk'],
#   ['beef', 'yogurt'],
#   ['berries', 'other vegetables'],
#   ['berries', 'whole milk'],
#   ['berries', 'yogurt'],
#   ['bottled beer', 'bottled water'],
#   ['bottled beer', 'other vegetables'],
#   ['bottled beer', 'rolls/buns'],
#   ['bottled beer', 'soda'],
#   ['bottled beer', 'whole milk'],
#   ['bottled water', 'citrus fruit'],
#   ['bottled water', 'fruit/vegetable juice'],
#   ['bottled water', 'margarine'],
#   ['bottled water', 'newspapers'],
#   ['bottled water', 'other vegetables'],
#   ['bottled water', 'pip fruit'],
#   ['bottled water', 'rolls/buns'],
#   ['bottled water', 'root vegetables'],
#   ['bottled water', 'sausage'],
#   ['bottled water', 'shopping bags'],
#   ['bottled water', 'soda'],
#   ['bottled water', 'tropical fruit'],
#   ['bottled water', 'whole milk'],
#   ['bottled water', 'yogurt'],
#   ['brown bread', 'other vegetables'],
#   ['brown bread', 'rolls/buns'],
#   ['brown bread', 'root vegetables'],
#   ['brown bread', 'sausage'],
#   ['brown bread', 'soda'],
#   ['brown bread', 'tropical fruit'],
#   ['brown bread', 'whole milk'],
#   ['brown bread', 'yogurt'],
#   ['butter', 'other vegetables'],
#   ['butter', 'rolls/buns'],
#   ['butter', 'root vegetables'],
#   ['butter', 'whipped/sour cream'],
#   ['butter', 'whole milk'],
#   ['butter', 'yogurt'],
#   ['butter milk', 'other vegetables'],
#   ['butter milk', 'whole milk'],
#   ['canned beer', 'rolls/buns'],
#   ['canned beer', 'shopping bags'],
#   ['canned beer', 'soda'],
#   ['chicken', 'other vegetables'],
#   ['chicken', 'root vegetables'],
#   ['chicken', 'whole milk'],
#   ['chocolate', 'other vegetables'],
#   ['chocolate', 'rolls/buns'],
#   ['chocolate', 'soda'],
#   ['chocolate', 'whole milk'],
#   ['citrus fruit', 'domestic eggs'],
#   ['citrus fruit', 'fruit/vegetable juice'],
#   ['citrus fruit', 'other vegetables'],
#   ['citrus fruit', 'pip fruit'],
#   ['citrus fruit', 'rolls/buns'],
#   ['citrus fruit', 'root vegetables'],
#   ['citrus fruit', 'sausage'],
#   ['citrus fruit', 'soda'],
#   ['citrus fruit', 'tropical fruit'],
#   ['citrus fruit', 'whipped/sour cream'],
#   ['citrus fruit', 'whole milk'],
#   ['citrus fruit', 'yogurt'],
#   ['coffee', 'other vegetables'],
#   ['coffee', 'rolls/buns'],
#   ['coffee', 'whole milk'],
#   ['cream cheese', 'other vegetables'],
#   ['cream cheese', 'whole milk'],
#   ['cream cheese', 'yogurt'],
#   ['curd', 'other vegetables'],
#   ['curd', 'rolls/buns'],
#   ['curd', 'root vegetables'],
#   ['curd', 'tropical fruit'],
#   ['curd', 'whipped/sour cream'],
#   ['curd', 'whole milk'],
#   ['curd', 'yogurt'],
#   ['dessert', 'other vegetables'],
#   ['dessert', 'whole milk'],
#   ['domestic eggs', 'other vegetables'],
#   ['domestic eggs', 'rolls/buns'],
#   ['domestic eggs', 'root vegetables'],
#   ['domestic eggs', 'soda'],
#   ['domestic eggs', 'tropical fruit'],
#   ['domestic eggs', 'whole milk'],
#   ['domestic eggs', 'yogurt'],
#   ['frankfurter', 'other vegetables'],
#   ['frankfurter', 'rolls/buns'],
#   ['frankfurter', 'root vegetables'],
#   ['frankfurter', 'sausage'],
#   ['frankfurter', 'soda'],
#   ['frankfurter', 'whole milk'],
#   ['frankfurter', 'yogurt'],
#   ['frozen vegetables', 'other vegetables'],
#   ['frozen vegetables', 'rolls/buns'],
#   ['frozen vegetables', 'root vegetables'],
#   ['frozen vegetables', 'whole milk'],
#   ['frozen vegetables', 'yogurt'],
#   ['fruit/vegetable juice', 'other vegetables'],
#   ['fruit/vegetable juice', 'rolls/buns'],
#   ['fruit/vegetable juice', 'root vegetables'],
#   ['fruit/vegetable juice', 'sausage'],
#   ['fruit/vegetable juice', 'shopping bags'],
#   ['fruit/vegetable juice', 'soda'],
#   ['fruit/vegetable juice', 'tropical fruit'],
#   ['fruit/vegetable juice', 'whole milk'],
#   ['fruit/vegetable juice', 'yogurt'],
#   ['ham', 'whole milk'],
#   ['hamburger meat', 'other vegetables'],
#   ['hamburger meat', 'whole milk'],
#   ['hard cheese', 'whole milk'],
#   ['hygiene articles', 'whole milk'],
#   ['long life bakery product', 'other vegetables'],
#   ['long life bakery product', 'whole milk'],
#   ['margarine', 'other vegetables'],
#   ['margarine', 'rolls/buns'],
#   ['margarine', 'root vegetables'],
#   ['margarine', 'soda'],
#   ['margarine', 'whole milk'],
#   ['margarine', 'yogurt'],
#   ['napkins', 'other vegetables'],
#   ['napkins', 'rolls/buns'],
#   ['napkins', 'soda'],
#   ['napkins', 'tropical fruit'],
#   ['napkins', 'whole milk'],
#   ['napkins', 'yogurt'],
#   ['newspapers', 'other vegetables'],
#   ['newspapers', 'rolls/buns'],
#   ['newspapers', 'root vegetables'],
#   ['newspapers', 'soda'],
#   ['newspapers', 'tropical fruit'],
#   ['newspapers', 'whole milk'],
#   ['newspapers', 'yogurt'],
#   ['oil', 'whole milk'],
#   ['onions', 'other vegetables'],
#   ['onions', 'whole milk'],
#   ['other vegetables', 'pastry'],
#   ['other vegetables', 'pip fruit'],
#   ['other vegetables', 'pork'],
#   ['other vegetables', 'rolls/buns'],
#   ['other vegetables', 'root vegetables'],
#   ['other vegetables', 'salty snack'],
#   ['other vegetables', 'sausage'],
#   ['other vegetables', 'shopping bags'],
#   ['other vegetables', 'soda'],
#   ['other vegetables', 'sugar'],
#   ['other vegetables', 'tropical fruit'],
#   ['other vegetables', 'waffles'],
#   ['other vegetables', 'whipped/sour cream'],
#   ['other vegetables', 'white bread'],
#   ['other vegetables', 'whole milk'],
#   ['other vegetables', 'yogurt'],
#   ['pastry', 'pip fruit'],
#   ['pastry', 'rolls/buns'],
#   ['pastry', 'root vegetables'],
#   ['pastry', 'sausage'],
#   ['pastry', 'shopping bags'],
#   ['pastry', 'soda'],
#   ['pastry', 'tropical fruit'],
#   ['pastry', 'whole milk'],
#   ['pastry', 'yogurt'],
#   ['pip fruit', 'rolls/buns'],
#   ['pip fruit', 'root vegetables'],
#   ['pip fruit', 'sausage'],
#   ['pip fruit', 'soda'],
#   ['pip fruit', 'tropical fruit'],
#   ['pip fruit', 'whole milk'],
#   ['pip fruit', 'yogurt'],
#   ['pork', 'rolls/buns'],
#   ['pork', 'root vegetables'],
#   ['pork', 'soda'],
#   ['pork', 'whole milk'],
#   ['rolls/buns', 'root vegetables'],
#   ['rolls/buns', 'sausage'],
#   ['rolls/buns', 'shopping bags'],
#   ['rolls/buns', 'soda'],
#   ['rolls/buns', 'tropical fruit'],
#   ['rolls/buns', 'whipped/sour cream'],
#   ['rolls/buns', 'whole milk'],
#   ['rolls/buns', 'yogurt'],
#   ['root vegetables', 'sausage'],
#   ['root vegetables', 'shopping bags'],
#   ['root vegetables', 'soda'],
#   ['root vegetables', 'tropical fruit'],
#   ['root vegetables', 'whipped/sour cream'],
#   ['root vegetables', 'whole milk'],
#   ['root vegetables', 'yogurt'],
#   ['salty snack', 'whole milk'],
#   ['sausage', 'shopping bags'],
#   ['sausage', 'soda'],
#   ['sausage', 'tropical fruit'],
#   ['sausage', 'whole milk'],
#   ['sausage', 'yogurt'],
#   ['shopping bags', 'soda'],
#   ['shopping bags', 'tropical fruit'],
#   ['shopping bags', 'whole milk'],
#   ['shopping bags', 'yogurt'],
#   ['sliced cheese', 'whole milk'],
#   ['soda', 'tropical fruit'],
#   ['soda', 'whipped/sour cream'],
#   ['soda', 'white bread'],
#   ['soda', 'whole milk'],
#   ['soda', 'yogurt'],
#   ['sugar', 'whole milk'],
#   ['tropical fruit', 'whipped/sour cream'],
#   ['tropical fruit', 'whole milk'],
#   ['tropical fruit', 'yogurt'],
#   ['waffles', 'whole milk'],
#   ['whipped/sour cream', 'whole milk'],
#   ['whipped/sour cream', 'yogurt'],
#   ['white bread', 'whole milk'],
#   ['whole milk', 'yogurt'],
#   ['bottled water', 'other vegetables', 'whole milk'],
#   ['butter', 'other vegetables', 'whole milk'],
#   ['citrus fruit', 'other vegetables', 'root vegetables'],
#   ['citrus fruit', 'other vegetables', 'whole milk'],
#   ['citrus fruit', 'whole milk', 'yogurt'],
#   ['curd', 'whole milk', 'yogurt'],
#   ['domestic eggs', 'other vegetables', 'whole milk'],
#   ['fruit/vegetable juice', 'other vegetables', 'whole milk'],
#   ['other vegetables', 'pastry', 'whole milk'],
#   ['other vegetables', 'pip fruit', 'whole milk'],
#   ['other vegetables', 'pork', 'whole milk'],
#   ['other vegetables', 'rolls/buns', 'root vegetables'],
#   ['other vegetables', 'rolls/buns', 'whole milk'],
#   ['other vegetables', 'rolls/buns', 'yogurt'],
#   ['other vegetables', 'root vegetables', 'tropical fruit'],
#   ['other vegetables', 'root vegetables', 'whole milk'],
#   ['other vegetables', 'root vegetables', 'yogurt'],
#   ['other vegetables', 'sausage', 'whole milk'],
#   ['other vegetables', 'soda', 'whole milk'],
#   ['other vegetables', 'tropical fruit', 'whole milk'],
#   ['other vegetables', 'tropical fruit', 'yogurt'],
#   ['other vegetables', 'whipped/sour cream', 'whole milk'],
#   ['other vegetables', 'whipped/sour cream', 'yogurt'],
#   ['other vegetables', 'whole milk', 'yogurt'],
#   ['rolls/buns', 'root vegetables', 'whole milk'],
#   ['rolls/buns', 'tropical fruit', 'whole milk'],
#   ['rolls/buns', 'whole milk', 'yogurt'],
#   ['root vegetables', 'tropical fruit', 'whole milk'],
#   ['root vegetables', 'whole milk', 'yogurt'],
#   ['soda', 'whole milk', 'yogurt'],
#   ['tropical fruit', 'whole milk', 'yogurt'],
#   ['whipped/sour cream', 'whole milk', 'yogurt']],
#  [(['citrus fruit'], 814),
#   (['semi-finished bread'], 174),
#   (['margarine'], 576),
#   (['tropical fruit'], 1032),
#   (['yogurt'], 1372),
#   (['coffee'], 571),
#   (['whole milk'], 2513),
#   (['pip fruit'], 744),
#   (['cream cheese'], 390),
#   (['other vegetables'], 1903),
#   (['condensed milk'], 101),
#   (['long life bakery product'], 368),
#   (['butter'], 545),
#   (['rolls/buns'], 1809),
#   (['UHT-milk'], 329),
#   (['bottled beer'], 792),
#   (['pot plants'], 170),
#   (['white bread'], 414),
#   (['bottled water'], 1087),
#   (['chocolate'], 488),
#   (['curd'], 524),
#   (['flour'], 171),
#   (['dishes'], 173),
#   (['beef'], 516),
#   (['frankfurter'], 580),
#   (['soda'], 1715),
#   (['chicken'], 422),
#   (['sugar'], 333),
#   (['fruit/vegetable juice'], 711),
#   (['newspapers'], 785),
#   (['packaged fruit/vegetables'], 128),
#   (['specialty bar'], 269),
#   (['butter milk'], 275),
#   (['pastry'], 875),
#   (['processed cheese'], 163),
#   (['detergent'], 189),
#   (['root vegetables'], 1072),
#   (['frozen dessert'], 106),
#   (['salty snack'], 372),
#   (['waffles'], 378),
#   (['candy'], 294),
#   (['canned beer'], 764),
#   (['sausage'], 924),
#   (['brown bread'], 638),
#   (['shopping bags'], 969),
#   (['beverages'], 256),
#   (['hamburger meat'], 327),
#   (['hygiene articles'], 324),
#   (['napkins'], 515),
#   (['pork'], 567),
#   (['berries'], 327),
#   (['whipped/sour cream'], 705),
#   (['grapes'], 220),
#   (['dessert'], 365),
#   (['domestic eggs'], 624),
#   (['spread cheese'], 110),
#   (['misc. beverages'], 279),
#   (['hard cheese'], 241),
#   (['cat food'], 229),
#   (['ham'], 256),
#   (['baking powder'], 174),
#   (['pickled vegetables'], 176),
#   (['oil'], 276),
#   (['chewing gum'], 207),
#   (['ice cream'], 246),
#   (['frozen vegetables'], 473),
#   (['canned fish'], 148),
#   (['seasonal products'], 140),
#   (['red/blush wine'], 189),
#   (['specialty chocolate'], 299),
#   (['flower (seeds)'], 102),
#   (['salt'], 106),
#   (['frozen meals'], 279),
#   (['canned vegetables'], 106),
#   (['onions'], 305),
#   (['herbs'], 160),
#   (['white wine'], 187),
#   (['sliced cheese'], 241),
#   (['pasta'], 148),
#   (['cling film/bags'], 112),
#   (['soft cheese'], 168),
#   (['cake bar'], 130),
#   (['frozen fish'], 115),
#   (['dish cleaner'], 103),
#   (['meat'], 254),
#   (['mustard'], 118),
#   (['liquor'], 109),
#   (['roll products'], 101),
#   (['citrus fruit', 'fruit/vegetable juice'], 102),
#   (['other vegetables', 'salty snack'], 106),
#   (['other vegetables', 'waffles'], 99),
#   (['citrus fruit', 'tropical fruit'], 196),
#   (['citrus fruit', 'whole milk'], 300),
#   (['citrus fruit', 'pip fruit'], 136),
#   (['citrus fruit', 'whipped/sour cream'], 107),
#   (['citrus fruit', 'domestic eggs'], 102),
#   (['other vegetables', 'tropical fruit'], 353),
#   (['rolls/buns', 'tropical fruit'], 242),
#   (['soda', 'tropical fruit'], 205),
#   (['sausage', 'tropical fruit'], 137),
#   (['brown bread', 'tropical fruit'], 105),
#   (['napkins', 'tropical fruit'], 99),
#   (['coffee', 'whole milk'], 184),
#   (['other vegetables', 'whole milk'], 736),
#   (['rolls/buns', 'whole milk'], 557),
#   (['soda', 'whole milk'], 394),
#   (['sausage', 'whole milk'], 294),
#   (['brown bread', 'whole milk'], 248),
#   (['napkins', 'whole milk'], 194),
#   (['oil', 'whole milk'], 111),
#   (['other vegetables', 'pip fruit'], 257),
#   (['other vegetables', 'pastry'], 222),
#   (['other vegetables', 'shopping bags'], 228),
#   (['other vegetables', 'whipped/sour cream'], 284),
#   (['rolls/buns', 'shopping bags'], 192),
#   (['rolls/buns', 'whipped/sour cream'], 144),
#   (['soda', 'whipped/sour cream'], 114),
#   (['sausage', 'shopping bags'], 154),
#   (['citrus fruit', 'yogurt'], 213),
#   (['citrus fruit', 'other vegetables'], 284),
#   (['citrus fruit', 'rolls/buns'], 165),
#   (['citrus fruit', 'soda'], 126),
#   (['citrus fruit', 'sausage'], 111),
#   (['other vegetables', 'yogurt'], 427),
#   (['rolls/buns', 'yogurt'], 338),
#   (['soda', 'yogurt'], 269),
#   (['sausage', 'yogurt'], 193),
#   (['brown bread', 'yogurt'], 143),
#   (['napkins', 'yogurt'], 121),
#   (['coffee', 'other vegetables'], 132),
#   (['coffee', 'rolls/buns'], 108),
#   (['other vegetables', 'rolls/buns'], 419),
#   (['other vegetables', 'soda'], 322),
#   (['other vegetables', 'sausage'], 265),
#   (['brown bread', 'other vegetables'], 184),
#   (['napkins', 'other vegetables'], 142),
#   (['rolls/buns', 'soda'], 377),
#   (['rolls/buns', 'sausage'], 301),
#   (['brown bread', 'rolls/buns'], 124),
#   (['napkins', 'rolls/buns'], 115),
#   (['sausage', 'soda'], 239),
#   (['brown bread', 'soda'], 124),
#   (['napkins', 'soda'], 118),
#   (['brown bread', 'sausage'], 105),
#   (['citrus fruit', 'root vegetables'], 174),
#   (['other vegetables', 'white bread'], 135),
#   (['other vegetables', 'sugar'], 106),
#   (['other vegetables', 'root vegetables'], 466),
#   (['other vegetables', 'pork'], 213),
#   (['rolls/buns', 'root vegetables'], 239),
#   (['soda', 'white bread'], 101),
#   (['brown bread', 'root vegetables'], 100),
#   (['cream cheese', 'yogurt'], 122),
#   (['butter', 'yogurt'], 144),
#   (['newspapers', 'yogurt'], 151),
#   (['root vegetables', 'yogurt'], 254),
#   (['frozen vegetables', 'yogurt'], 122),
#   (['cream cheese', 'other vegetables'], 135),
#   (['butter', 'other vegetables'], 197),
#   (['bottled beer', 'other vegetables'], 159),
#   (['chicken', 'other vegetables'], 176),
#   (['newspapers', 'other vegetables'], 190),
#   (['frozen vegetables', 'other vegetables'], 175),
#   (['onions', 'other vegetables'], 140),
#   (['butter', 'rolls/buns'], 132),
#   (['bottled beer', 'rolls/buns'], 134),
#   (['newspapers', 'rolls/buns'], 194),
#   (['pork', 'rolls/buns'], 111),
#   (['frozen vegetables', 'rolls/buns'], 100),
#   (['bottled beer', 'soda'], 167),
#   (['newspapers', 'soda'], 144),
#   (['root vegetables', 'soda'], 183),
#   (['pork', 'soda'], 117),
#   (['root vegetables', 'sausage'], 147),
#   (['bottled beer', 'bottled water'], 155),
#   (['newspapers', 'tropical fruit'], 116),
#   (['root vegetables', 'tropical fruit'], 207),
#   (['cream cheese', 'whole milk'], 162),
#   (['butter', 'whole milk'], 271),
#   (['bottled beer', 'whole milk'], 201),
#   (['white bread', 'whole milk'], 168),
#   (['chicken', 'whole milk'], 173),
#   (['sugar', 'whole milk'], 148),
#   (['newspapers', 'whole milk'], 269),
#   (['root vegetables', 'whole milk'], 481),
#   (['pork', 'whole milk'], 218),
#   (['ham', 'whole milk'], 113),
#   (['frozen vegetables', 'whole milk'], 201),
#   (['onions', 'whole milk'], 119),
#   (['sliced cheese', 'whole milk'], 106),
#   (['butter', 'whipped/sour cream'], 100),
#   (['root vegetables', 'shopping bags'], 126),
#   (['root vegetables', 'whipped/sour cream'], 168),
#   (['butter', 'root vegetables'], 127),
#   (['chicken', 'root vegetables'], 107),
#   (['newspapers', 'root vegetables'], 113),
#   (['pork', 'root vegetables'], 134),
#   (['frozen vegetables', 'root vegetables'], 114),
#   (['bottled water', 'citrus fruit'], 133),
#   (['margarine', 'yogurt'], 140),
#   (['margarine', 'other vegetables'], 194),
#   (['margarine', 'rolls/buns'], 145),
#   (['margarine', 'soda'], 100),
#   (['bottled water', 'yogurt'], 226),
#   (['curd', 'yogurt'], 170),
#   (['beef', 'yogurt'], 115),
#   (['frankfurter', 'yogurt'], 110),
#   (['fruit/vegetable juice', 'yogurt'], 184),
#   (['bottled water', 'other vegetables'], 244),
#   (['chocolate', 'other vegetables'], 125),
#   (['curd', 'other vegetables'], 169),
#   (['beef', 'other vegetables'], 194),
#   (['frankfurter', 'other vegetables'], 162),
#   (['fruit/vegetable juice', 'other vegetables'], 207),
#   (['butter milk', 'other vegetables'], 102),
#   (['hamburger meat', 'other vegetables'], 136),
#   (['dessert', 'other vegetables'], 114),
#   (['bottled water', 'rolls/buns'], 238),
#   (['chocolate', 'rolls/buns'], 116),
#   (['curd', 'rolls/buns'], 99),
#   (['beef', 'rolls/buns'], 134),
#   (['frankfurter', 'rolls/buns'], 189),
#   (['fruit/vegetable juice', 'rolls/buns'], 143),
#   (['canned beer', 'rolls/buns'], 111),
#   (['bottled water', 'soda'], 285),
#   (['bottled water', 'sausage'], 118),
#   (['chocolate', 'soda'], 133),
#   (['frankfurter', 'soda'], 111),
#   (['frankfurter', 'sausage'], 99),
#   (['fruit/vegetable juice', 'soda'], 181),
#   (['canned beer', 'soda'], 136),
#   (['fruit/vegetable juice', 'sausage'], 99),
#   (['bottled water', 'margarine'], 101),
#   (['bottled water', 'fruit/vegetable juice'], 140),
#   (['margarine', 'whole milk'], 238),
#   (['bottled water', 'tropical fruit'], 182),
#   (['curd', 'tropical fruit'], 101),
#   (['fruit/vegetable juice', 'tropical fruit'], 135),
#   (['bottled water', 'whole milk'], 338),
#   (['chocolate', 'whole milk'], 164),
#   (['curd', 'whole milk'], 257),
#   (['beef', 'whole milk'], 209),
#   (['frankfurter', 'whole milk'], 202),
#   (['fruit/vegetable juice', 'whole milk'], 262),
#   (['butter milk', 'whole milk'], 114),
#   (['salty snack', 'whole milk'], 110),
#   (['waffles', 'whole milk'], 125),
#   (['hamburger meat', 'whole milk'], 145),
#   (['dessert', 'whole milk'], 135),
#   (['bottled water', 'pip fruit'], 104),
#   (['bottled water', 'shopping bags'], 108),
#   (['curd', 'whipped/sour cream'], 103),
#   (['fruit/vegetable juice', 'shopping bags'], 105),
#   (['canned beer', 'shopping bags'], 112),
#   (['margarine', 'root vegetables'], 109),
#   (['bottled water', 'newspapers'], 111),
#   (['bottled water', 'root vegetables'], 154),
#   (['curd', 'root vegetables'], 107),
#   (['beef', 'root vegetables'], 171),
#   (['frankfurter', 'root vegetables'], 100),
#   (['fruit/vegetable juice', 'root vegetables'], 118),
#   (['tropical fruit', 'yogurt'], 288),
#   (['whole milk', 'yogurt'], 551),
#   (['pip fruit', 'yogurt'], 177),
#   (['pastry', 'yogurt'], 174),
#   (['shopping bags', 'yogurt'], 150),
#   (['berries', 'yogurt'], 104),
#   (['whipped/sour cream', 'yogurt'], 204),
#   (['domestic eggs', 'yogurt'], 141),
#   (['pip fruit', 'rolls/buns'], 137),
#   (['pip fruit', 'soda'], 131),
#   (['pip fruit', 'sausage'], 106),
#   (['long life bakery product', 'other vegetables'], 105),
#   (['berries', 'other vegetables'], 101),
#   (['domestic eggs', 'other vegetables'], 219),
#   (['pastry', 'rolls/buns'], 206),
#   (['domestic eggs', 'rolls/buns'], 154),
#   (['pastry', 'soda'], 207),
#   (['shopping bags', 'soda'], 242),
#   (['domestic eggs', 'soda'], 122),
#   (['pastry', 'sausage'], 123),
#   (['tropical fruit', 'whole milk'], 416),
#   (['pip fruit', 'tropical fruit'], 201),
#   (['pastry', 'tropical fruit'], 130),
#   (['shopping bags', 'tropical fruit'], 133),
#   (['tropical fruit', 'whipped/sour cream'], 136),
#   (['domestic eggs', 'tropical fruit'], 112),
#   (['pip fruit', 'whole milk'], 296),
#   (['long life bakery product', 'whole milk'], 133),
#   (['pastry', 'whole milk'], 327),
#   (['shopping bags', 'whole milk'], 241),
#   (['hygiene articles', 'whole milk'], 126),
#   (['berries', 'whole milk'], 116),
#   (['whipped/sour cream', 'whole milk'], 317),
#   (['domestic eggs', 'whole milk'], 295),
#   (['hard cheese', 'whole milk'], 99),
#   (['pastry', 'pip fruit'], 105),
#   (['pastry', 'shopping bags'], 117),
#   (['pip fruit', 'root vegetables'], 153),
#   (['pastry', 'root vegetables'], 108),
#   (['domestic eggs', 'root vegetables'], 141),
#   (['bottled water', 'other vegetables', 'whole milk'], 106),
#   (['fruit/vegetable juice', 'other vegetables', 'whole milk'], 103),
#   (['curd', 'whole milk', 'yogurt'], 99),
#   (['domestic eggs', 'other vegetables', 'whole milk'], 121),
#   (['tropical fruit', 'whole milk', 'yogurt'], 149),
#   (['whipped/sour cream', 'whole milk', 'yogurt'], 107),
#   (['butter', 'other vegetables', 'whole milk'], 113),
#   (['root vegetables', 'tropical fruit', 'whole milk'], 118),
#   (['root vegetables', 'whole milk', 'yogurt'], 143),
#   (['other vegetables', 'rolls/buns', 'yogurt'], 113),
#   (['citrus fruit', 'other vegetables', 'root vegetables'], 102),
#   (['other vegetables', 'rolls/buns', 'root vegetables'], 120),
#   (['citrus fruit', 'other vegetables', 'whole milk'], 128),
#   (['other vegetables', 'rolls/buns', 'whole milk'], 176),
#   (['other vegetables', 'sausage', 'whole milk'], 100),
#   (['other vegetables', 'soda', 'whole milk'], 137),
#   (['other vegetables', 'root vegetables', 'yogurt'], 127),
#   (['other vegetables', 'pork', 'whole milk'], 100),
#   (['other vegetables', 'root vegetables', 'tropical fruit'], 121),
#   (['other vegetables', 'root vegetables', 'whole milk'], 228),
#   (['rolls/buns', 'root vegetables', 'whole milk'], 125),
#   (['other vegetables', 'pastry', 'whole milk'], 104),
#   (['other vegetables', 'pip fruit', 'whole milk'], 133),
#   (['other vegetables', 'tropical fruit', 'whole milk'], 168),
#   (['other vegetables', 'whipped/sour cream', 'whole milk'], 144),
#   (['rolls/buns', 'tropical fruit', 'whole milk'], 108),
#   (['citrus fruit', 'whole milk', 'yogurt'], 101),
#   (['other vegetables', 'tropical fruit', 'yogurt'], 121),
#   (['other vegetables', 'whipped/sour cream', 'yogurt'], 100),
#   (['other vegetables', 'whole milk', 'yogurt'], 219),
#   (['rolls/buns', 'whole milk', 'yogurt'], 153),
#   (['soda', 'whole milk', 'yogurt'], 103)])

# %%
# To be implemented
def generate_association_rules(transactions, minsup, minconf):
    '''Mine the association rules from transactions
    Args:
        transactions (list): a list of lists, where each component list is a list of string representing a transaction
        minsup (float): specifies the minsup for mining
        minconf (float): specifies the minconf for mining

    Returns:
        list: a list of association rule, each rule is represented as a list of string

    Example:
        Output: [['root vegetables', 'rolls/buns','=>', 'other vegetables'],['root vegetables', 'yogurt','=>','other vegetables']]
        The meaning of the output is as follows: {root vegetables, rolls/buns} => {other vegetables} and {root vegetables, yogurt} => {other vegetables} are the two associated rules found by the algorithm
    

    '''
    rules = []
    frequent_itemsets, support_count = generate_frequent_itemset(transactions, minsup)
#     print(frequent_itemsets)
    i = 0
    for itemset_k in frequent_itemsets:
#         print("check itemset:",i+1)
        i += 1 
        length = len(itemset_k)
        if length < 2:
#             print("continue")
            continue
        consequence_1 = [''.join(x) for x in list(itertools.combinations(itemset_k, 1))]
#         print("consequence_1:",consequence_1)
        consequence_1, rules = prune(itemset_k, consequence_1,minconf,rules, support_count)
        if consequence_1:
            rules = apriori_genrules(itemset_k, consequence_1, minconf, rules, support_count)
          
    print(rules)
    
    return rules

def prune(itemset_k, consequence_m, minconf, rules, support_count):
    rules = [x for x in rules if x !=[]]
    templist_remove = []
    for consequence in consequence_m:    
        left = [x for x in itemset_k]
        if isinstance(consequence, list):
            for y in consequence:
                left.remove(y)
        else:
            left.remove(consequence)
#         print("left:",left, "  --  right:",consequence)
        conf = find_support(itemset_k, support_count) / find_support(left, support_count)
#         print("confidence level:",conf)
        if conf >= minconf:
            new_rule = []
            new_rule.extend(left)
            new_rule.append("=>")
            new_rule.append(consequence)
#             print("rules:",rules)
#             print("new_rule:",new_rule)
            rules.append(new_rule)
            
        else:
            templist_remove.append(consequence)
    
    for temp in templist_remove:
        consequence_m.remove(temp); 
#     print("after remove:",consequence_m)
    return consequence_m, rules


def apriori_genrules(itemset_k, consequence_m, minconf, rules, support_count):
    rules = [x for x in rules if x !=[]]
    k = len(itemset_k)
    
    if isinstance(consequence_m[0], list):
        m = len(consequence_m[0])
    else:
        m = 1
#     print("m:",m)
#     print("consequence_m",consequence_m)
    temp = [x for x in consequence_m]
    while (k >= m + 1 and temp):
        print("True:",consequence_m)
        consequence_m_1 = apriori_gen(temp)
        temp = []
        temp,rules = prune(itemset_k, consequence_m_1, minconf, rules, support_count)
        m += 1
    return rules

def find_support(itemset_k, support_count):
    count = 0
    for x in support_count:
        if len(x[0])==len(itemset_k):
            if check_same_array(x[0], itemset_k):
                count = x[1]
    return count
    

def apriori_gen(consequence_m):
    templist = []
    if isinstance(consequence_m[0], list):
        m = len(consequence_m[0])

    else:
        m = 1
        
    for x in consequence_m:
        print("x:",x)
        if m == 1:
            templist.append(x)
        else:
            for y in x:
                if not y in templist:
                    templist.append(y)
        
#     print("templist",templist)
    consequence_m_1 = [list(x) for x in list(itertools.combinations(templist, m+1))]
#     print("consequence_m_1:",consequence_m_1)
    return consequence_m_1

# %%
transactions = read_csv("Data/Groceries100.csv")
rules = generate_association_rules(transactions, 0.05, 0.3)

# b = [['1','2'],['2','3'],['1','3'],['4']]
# a = apriori_gen(b)
print(rules)
# Out:
# transaction: 100
# frequent_k: [[26], [91], [98], [27], [97], [60], [13], [73], [10], [24], [30], [82], [89], [43], [57], [63], [33], [74], [17], [77], [12], [7], [94], [58]]
#
# loop  2  start
#
# loop  3  start
# final frequent itemsets: [['citrus fruit'], ['tropical fruit'], ['yogurt'], ['coffee'], ['whole milk'], ['other vegetables'], ['butter'], ['rolls/buns'], ['bottled water'], ['chocolate'], ['curd'], ['soda'], ['sugar'], ['fruit/vegetable juice'], ['newspapers'], ['pastry'], ['detergent'], ['root vegetables'], ['canned beer'], ['sausage'], ['brown bread'], ['berries'], ['whipped/sour cream'], ['oil'], ['other vegetables', 'rolls/buns'], ['other vegetables', 'root vegetables'], ['other vegetables', 'whole milk'], ['rolls/buns', 'sausage'], ['rolls/buns', 'soda'], ['whole milk', 'yogurt']]
# check itemset: 1
# check itemset: 2
# check itemset: 3
# check itemset: 4
# check itemset: 5
# check itemset: 6
# check itemset: 7
# check itemset: 8
# check itemset: 9
# check itemset: 10
# check itemset: 11
# check itemset: 12
# check itemset: 13
# check itemset: 14
# check itemset: 15
# check itemset: 16
# check itemset: 17
# check itemset: 18
# check itemset: 19
# check itemset: 20
# check itemset: 21
# check itemset: 22
# check itemset: 23
# check itemset: 24
# check itemset: 25
# check itemset: 26
# True: ['other vegetables']
# x: other vegetables
# templist ['other vegetables']
# consequence_m_1: []
# check itemset: 27
# True: ['whole milk']
# x: whole milk
# templist ['whole milk']
# consequence_m_1: []
# check itemset: 28
# True: ['rolls/buns']
# x: rolls/buns
# templist ['rolls/buns']
# consequence_m_1: []
# check itemset: 29
# True: ['rolls/buns']
# x: rolls/buns
# templist ['rolls/buns']
# consequence_m_1: []
# check itemset: 30
# True: ['whole milk']
# x: whole milk
# templist ['whole milk']
# consequence_m_1: []
# [['root vegetables', '=>', 'other vegetables'], ['other vegetables', '=>', 'whole milk'], ['sausage', '=>', 'rolls/buns'], ['soda', '=>', 'rolls/buns'], ['yogurt', '=>', 'whole milk']]
# [['root vegetables', '=>', 'other vegetables'], ['other vegetables', '=>', 'whole milk'], ['sausage', '=>', 'rolls/buns'], ['soda', '=>', 'rolls/buns'], ['yogurt', '=>', 'whole milk']]

# %%
def main():

    if len(sys.argv) != 3 and len(sys.argv) != 4:
        print("Wrong command format, please follwoing the command format below:")
        print("python assoc-rule-miner-template.py csv_filepath minsup")
        print("python assoc-rule-miner-template.py csv_filepath minsup minconf")
        exit(0)

    
    if len(sys.argv) == 3:
        transactions = read_csv(sys.argv[1])
        result,_ = generate_frequent_itemset(transactions, float(sys.argv[2]))

        # store frequent itemsets found by your algorithm for automatic marking
        with open('.'+os.sep+'Output'+os.sep+'frequent_itemset_result.txt', 'w') as f:
            for items in result:
                output_str = '{'
                for e in items:
                    output_str += e
                    output_str += ','

                output_str = output_str[:-1]
                output_str += '}\n'
                f.write(output_str)

    elif len(sys.argv) == 4:
        transactions = read_csv(sys.argv[1])
        minsup = float(sys.argv[2])
        minconf = float(sys.argv[3])
        result = generate_association_rules(transactions, minsup, minconf)

        # store associative rule found by your algorithm for automatic marking
        with open('.'+os.sep+'Output'+os.sep+'assoc-rule-result.txt', 'w') as f:
            for items in result:
                output_str = '{'
                for e in items:
                    if e == '=>':
                        output_str = output_str[:-1]
                        output_str += '} => {'
                    else:
                        output_str += e
                        output_str += ','

                output_str = output_str[:-1]
                output_str += '}\n'
                f.write(output_str)

# %%
main()
